# %% [markdown]
# # Intro slide

# %%
#| remove-cell
/gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Intro.ipynb

cd /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Intro.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Initial_Neutrophil_Query.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Reference_Neutrophil_Query.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Intro.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Intro.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
cp /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/Analysis_LAM/Intro.ipynb /gpfs01/home/mzxcs8/Extra/Neutrophil LAM Phenotype - Johnson Lab/HTML/content
jupyter-book build . --builder html
# Out:
#   Cell In[1], line 2
#     gpfs01/home/mzxcs8/Extra/Neutrophil(LAM, Phenotype, -, Johnson, Lab/Analysis_LAM/Intro.ipynb)
#                                                          ^
# SyntaxError: invalid syntax

# %%
#| remove-cell
from tag_cells import tag_cells

# %%
#| remove-cell
tag_cells(
    "Intro.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
tag_cells(
    "Preprocessing.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
tag_cells(
    "Validation.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
tag_cells(
    "RNA_velocity.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
tag_cells(
    "Final_annotation.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
tag_cells(
    "GSEA.ipynb",
    {
        "#| remove-cell": ["remove-cell"],
        "#| hide-input": ["hide-input"],
        "#| hide-output": ["hide-output"],
    }
)
# Out:
# ✅ Tags added. Saved to Intro.ipynb
# ✅ Tags added. Saved to Preprocessing.ipynb
# ✅ Tags added. Saved to Validation.ipynb
# ✅ Tags added. Saved to RNA_velocity.ipynb
# ✅ Tags added. Saved to Final_annotation.ipynb
# ✅ Tags added. Saved to GSEA.ipynb
